# %% [markdown]
# # Training

# %%
import torch
import random
import numpy as np

# from torchvision import transforms
from PIL import Image
import os
import pandas as pd
import json

from matplotlib import pyplot as plt

from ipynb.fs.full.read_in_data import read_in_data
from validation import predict_knn, predict_knn_zoo


from transforms import train_transforms, val_transforms
from dataset import ContrastiveLearningDataset, SimpleDataset

#seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %% [markdown]
# ## Loading data

# %%
with open("../public_dataset/reference_images_part1.json") as f:
    ref_json = json.load(f)

dir_str = "../public_dataset/reference_images_part1"
df = read_in_data(dir_str, ref_json)

df = df.sort_values('category_id')
df = df.reset_index(drop=True)
df.head()
# Out:
#     id image_id                  bbox category_id  \
# 0  155       33   [116, 97, 411, 126]           1
# 1   33        6  [573, 246, 164, 298]           1
# 2   32        6  [114, 269, 363, 223]           1
# 3   30        6  [622, 218, 374, 220]           1
# 4   29        6  [743, 486, 354, 132]           1
#
#                                                  img
# 0  <PIL.Image.Image image mode=RGB size=411x126 a...
# 1  <PIL.Image.Image image mode=RGB size=164x298 a...
# 2  <PIL.Image.Image image mode=RGB size=363x223 a...
# 3  <PIL.Image.Image image mode=RGB size=374x220 a...
# 4  <PIL.Image.Image image mode=RGB size=354x132 a...

# %%
from torchvision.transforms import transforms as T

# %%
id = 1
img = df['img'][id]
print(df['category_id'][id])

img = train_transforms(img)

print(img.shape)

plt.imshow(img.permute(1, 2, 0))
# Out:
# 1
# torch.Size([3, 224, 224])

# %%
images = df['img']
labels = df['category_id']

val_labels = [4, 5, 6]
val_ids = ~labels.isin(val_labels) # TODO

val_images = images[val_ids].reset_index(drop=True)
val_labels = labels[val_ids].reset_index(drop=True)

train_ids = ~val_ids

train_images = images[train_ids].reset_index(drop=True)
train_labels = labels[train_ids].reset_index(drop=True)

# %%
train_dataset = ContrastiveLearningDataset(train_images, train_labels, train_transforms)
# val_dataset = SimpleDataset(train_images, train_labels, val_transforms)
val_dataset = ContrastiveLearningDataset(train_images, train_labels, val_transforms)

# %%
id_ = random.randrange(0, len(train_dataset))

image, label = train_dataset[id_]

# f, axarr = plt.subplots(1,2) 

# axarr[0].imshow(image_1.permute(1, 2, 0))
# axarr[1].imshow(image_2.permute(1, 2, 0))

# sign, weight

print(image.mean(), image.max(), image.min())
# Out:
# tensor(0.2769) tensor(0.9961) tensor(0.)

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"DEVICE: {DEVICE}")
# Out:
# DEVICE: cuda

# %%
BATCH_SIZE = 8

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    BATCH_SIZE, 
    shuffle=True, 
    num_workers=0,
    pin_memory=False,
)

# %% [markdown]
# ## Training loop

# %%
EPOCHS = 100

# %%
from ipynb.fs.full.fb_model_extractor import DeiTForImageClassificationWithTeacher
from transformers import AutoFeatureExtractor
# Out:
# torch.Size([1, 384])

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained('facebook/deit-small-distilled-patch16-224') # TODO to nie jest dotrenowywane
model = DeiTForImageClassificationWithTeacher.from_pretrained('facebook/deit-small-distilled-patch16-224').to(DEVICE)

# from model import ImageEmbeddingWithTransofmers

# model = ImageEmbeddingWithTransofmers(128, freeze_backbone=True, device=DEVICE)
# model.load_state_dict(torch.load("transformers_based.params"))
# optimizer = torch.optim.Adam(model.parameters())

# %%
from losses import ContrastiveLoss, CosineSimilarityLoss

loss_function = CosineSimilarityLoss(pos_weight=3)
# loss_function = ContrastiveLoss(np.sqrt(out_dim))
# loss_function2 = ContrastiveLoss(np.sqrt(out_dim), reduction="NONE")
# cos = torch.nn.CosineSimilarity(dim=1, eps=1e-6)

# def contrastive_learning_loss(v_1, v_2, weight, sign):
#     cos_sim = cos(v_1, v_2)
#     loss = - weight * cos_sim * sign
#     return loss.mean()

# %%
from sklearn.decomposition import PCA

def validate(model, dataset):
    embeddings = []
    labels = []
    for i in range(len(dataset)):
        image, label = dataset[i]
        image = image.to(device=DEVICE)
        label = label
        emb = model(**feature_extractor(image.cpu(), return_tensors='pt'))
        embeddings.append(emb[0].detach().cpu().numpy())
        labels.append(label)

    emb4lab_dict = {}
    for e, l in zip(embeddings, labels):
        if l not in emb4lab_dict.keys():
            emb4lab_dict[l] = [e]
        else:
            emb4lab_dict[l].append(e)
    for l in emb4lab_dict.keys():
        emb4lab_dict[l] = np.mean(np.array(emb4lab_dict[l]), axis=0)
    
    lbl_dsts = {}
    for e, l in zip(embeddings, labels):
        dst = np.sum(np.abs(e - emb4lab_dict[l]))
        if l not in lbl_dsts.keys():
            lbl_dsts[l] = [dst]
        else:
            lbl_dsts[l].append(dst)
    for l in lbl_dsts.keys():
        lbl_dsts[l] = np.mean(np.array(lbl_dsts[l]), axis=0)
        print(f"LABEL: {l} - MEAN DST: {lbl_dsts[l]}")
    
    embeddings = np.array(embeddings)
    labels = np.array(labels)
    
    pca = PCA()
    pca.fit(embeddings)
    emb2d = pca.transform(embeddings)
    plt.scatter(emb2d[:,0], emb2d[:,1], c=labels)
    plt.show()

# %%
with open("../public_dataset/images_part1_valid.json") as f:
    ref_json = json.load(f)

dir_str = "../public_dataset/images_part1_valid"
valid_data = read_in_data(dir_str, ref_json)

with open("../public_dataset/reference_images_part1.json") as f:
    ref_json = json.load(f)

dir_str = "../public_dataset/reference_images_part1"
ref_data = read_in_data(dir_str, ref_json)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-65cd095cd1b1> in <module>
#       3
#       4 dir_str = "../public_dataset/images_part1_valid"
# ----> 5 valid_data = read_in_data(dir_str, ref_json)
#       6
#       7 with open("../public_dataset/reference_images_part1.json") as f:
#
# c:\Users\User\Documents\HACKATON\knum_golem_hackathon\read_in_data.ipynb in read_in_data(dir_str, ref_json)
#      35     "\n",
#      36     "    id_to_img = {}\n",
# ---> 37     "    df = pd.DataFrame(columns=['id', 'image_id', 'bbox', 'category_id', 'img'])\n",
#      38     "\n",
#      39     "    for line in ref_json[\"images\"]:\n",
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1627
#    1628             if missing:
# -> 1629                 self._setitem_with_indexer_missing(indexer, value)
#    1630                 return
#    1631
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1920                 value = Series(value, index=self.obj.columns, name=indexer)
#    1921
# -> 1922             self.obj._mgr = self.obj.append(value)._mgr
#    1923             self.obj._maybe_update_cacher(clear=True)
#    1924
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     296     )
#     297
# --> 298     return op.get_result()
#     299
#     300
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     518                 mgrs_indexers.append((obj._mgr, indexers))
#     519
# --> 520             new_data = concatenate_block_managers(
#     521                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     522             )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\internals\concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      81         else:
#      82             b = make_block(
# ---> 83                 _concatenate_join_units(join_units, concat_axis, copy=copy),
#      84                 placement=placement,
#      85                 ndim=len(axes),
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\internals\concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     341             concat_values = np.atleast_2d(concat_values)
#     342     else:
# --> 343         concat_values = concat_compat(to_concat, axis=concat_axis)
#     344
#     345     return concat_values
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\dtypes\concat.py in concat_compat(to_concat, axis)
#     169                 to_concat = [x.astype("object") for x in to_concat]
#     170
# --> 171     return np.concatenate(to_concat, axis=axis)
#     172
#     173
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
def dist_func(v1, v2):
    return ((v1 - v2)** 2).sum()

# %%
df = predict_knn_zoo(model, ref_data.reset_index(drop=True), valid_data, k=1, feature_extractor=feature_extractor)
accuracy = (df.pred_category == df.category_id).mean()
print(accuracy)
# Out:
# 0it [00:00, ?it/s]
# tensor(5)
# tensor(10)
# tensor(8)
# tensor(10)
# tensor(8)
# tensor(5)
# tensor(10)
# tensor(8)
# tensor(5)
# tensor(8)
# tensor(10)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(8)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(8)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(8)
# tensor(6)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(6)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(10)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(10)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(6)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(1)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(2)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(9)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(1)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(5)
# tensor(8)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(2)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(2)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(9)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(2)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(4)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(13)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(4)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(2)
# tensor(5)
# tensor(10)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(8)
# tensor(10)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(6)
# tensor(9)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(2)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(5)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(1)
# tensor(5)
# tensor(9)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(1)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(9)
# tensor(8)
# tensor(1)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(5)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(8)
# tensor(8)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(1)
# tensor(1)
# tensor(10)
# tensor(9)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(10)
# tensor(10)
# tensor(5)
# tensor(10)
# tensor(2)
# tensor(10)
# tensor(6)
# tensor(13)
# tensor(6)
# tensor(5)
# tensor(6)
# tensor(10)
# tensor(6)
# tensor(10)
# tensor(2)
# tensor(6)
# tensor(9)
# tensor(5)
# tensor(9)
# tensor(9)
# tensor(6)
# tensor(5)
# tensor(9)
# tensor(2)
# tensor(10)
# tensor(10)
# tensor(9)

# %%
torch.cuda.empty_cache()
LOSS_COUNT_SAMPLES = 24

validate(model, val_dataset)
optimizer.zero_grad()
for epoch in range(EPOCHS):
    losses = []
    all_labels = []
    all_ys = []
    for i, data in enumerate(train_loader, 0):
        torch.cuda.empty_cache()
        images, labels = data
        images = images.to(device=DEVICE)
        images = [np.array(image.cpu(), dtype=np.uint8) for image in images]
        
        ys = model(**feature_extractor(images, return_tensors='pt'))
        
        all_ys.append(ys)
        all_labels.append(labels)
        
        if (i+1) % (LOSS_COUNT_SAMPLES // BATCH_SIZE) == 0:
            loss = loss_function(torch.cat(all_ys), torch.cat(all_labels))
            loss.backward()
            optimizer.step()
            losses.append(loss.cpu().item())
            all_ys = []
            all_labels = []
            optimizer.zero_grad()
        
    total_loss = np.mean(losses)
    print(f"Epoch: {epoch + 1}/{EPOCHS}: Loss: {total_loss}")
    if epoch % 5 == 0:
        validate(model, val_dataset)
    
        # YOUR CODE HERE
        
        # TODO: walidacja, wypisywanie lossów itd
        # END YOUR CODE

# %%
# for epoch in range(EPOCHS):
#     if epoch == 3:
#         optimizer = torch.optim.Adam(model.get_backbone_params())
#     losses = []
#     for i, data in enumerate(train_loader, 0):
#         image_1, image_2, sign, weight = data
#         image_1 = image_1.to(device=DEVICE)
#         image_2 = image_2.to(device=DEVICE)
#         sign = sign.to(device=DEVICE)
#         weight = None # weight.to(device=DEVICE)

#         optimizer.zero_grad()
        
#         v_1 = model(image_1)
#         v_2 = model(image_2)
        
#         loss = loss_function(v_1, v_2, sign, weight=weight)
#         # loss2 = loss_function2(v_1, v_2, sign, weight=weight)
        
#         # print(sign)
#         # print(weight)
#         # print(loss2)
        
#         loss.backward()
#         optimizer.step()
#         losses.append(loss.cpu().item())
#         if i % 10 == 0:
#             print(f"i: {i}: {loss}")
        
#     total_loss = np.mean(losses)
#     print(f"Epoch: {epoch + 1}/{EPOCHS}: Loss: {total_loss}")
#     validate(model, val_dataset)
#         # YOUR CODE HERE
        
#         # TODO: walidacja, wypisywanie lossów itd
#         # END YOUR CODE
